# %%
# %cd /content/drive/MyDrive/GitHub/
# !ls

# %%
# !git clone https://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@github.com/ttrogers/DemoRepo.git
# Out:
# Cloning into 'DemoRepo'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (7/7), done.

# %%
# %cd DemoRepo
# Out:
# /content/drive/MyDrive/GitHub/DemoRepo

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	GitAndClolabDemo.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .

# %%
# !git config user.email "ttrogers@gmail.com"
# !git config user.name "Tim Rogers"

# %%
# !git commit -m "Added this notebook"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@9f57125d0e5b.(none)')
